# %%
from __future__ import print_function, division
from gurobipy import Model, GRB, quicksum, LinExpr
import networkx as nx
import pickle
import numpy, random

# %%
def MIP_IM():
    budget = 25
    m = 10
    for index in range(24):
        with open('../MIP/data/networks_prob/graph_spa_500_'+str(index)+'.pickle', "rb") as f:
            main_graph = pickle.load(f)
    
            samples = []
            for j in range(m):
                G = nx.DiGraph()
                for u in main_graph.nodes():
                    G.add_node(u)
                for u,v in main_graph.edges():
                    if main_graph[u][v]['p']> random.random():
                        G.add_edge(u, v)
                samples.append(G)
                
                
            model = Model('influence_maximization_'+str(index))
            mvars = []
            #active nodes
            avars = []
            #seed nodes
            svars = []
            var_seed_dict = {}
            var_active_dict = {}

            for j in range(len(main_graph.nodes())):
                s = model.addVar(lb=0.0, ub=1.0, vtype=GRB.BINARY)
                svars.append(s)
                var_seed_dict[j] = s

            for sample_index, sample in enumerate(samples):
                for j in range(len(main_graph.nodes())):
                    a = model.addVar(lb=0.0, ub=1.0, vtype=GRB.BINARY)
                    avars.append(a)
                    var_active_dict[(sample_index,j)] = a    

            mvars.append(avars)
            mvars.append(svars)

            obj_expr = quicksum(avars)
            model.setObjective(obj_expr, GRB.MAXIMIZE)
            model.addConstr(quicksum(svars), GRB.LESS_EQUAL, budget)
            for sample_index, sample in enumerate(samples):
                for i in range(len(main_graph.nodes())):
                    neighbors = sample.in_edges(i) 
                    e = len(neighbors)
                    ai = var_active_dict[(sample_index,i)]
                    si = var_seed_dict[i]
                    neighbors_vars = []
                    for neighbor in neighbors:
                        neighbors_vars.append(var_active_dict[(sample_index,neighbor[0])])
                    expr = (e+1)*ai-si-quicksum(neighbors_vars)
                    model.addConstr(expr, GRB.GREATER_EQUAL, 0)
                    model.addConstr(expr, GRB.LESS_EQUAL, e)
            try:
                model.optimize()
            except e:
                print(e)
                
            with open('../Git/influence_maximization/experiments/im500/results/mip/base10/output_'+str(index)+'.txt', "w") as of:    
                for key,value in var_seed_dict.items():
                    if(value.x > 0):
                        print(key, file = of)

# %%
MIP_IM()
# Out:
# Optimize a model with 10001 rows, 5500 columns and 25390 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6195 rows and 3103 columns
# Presolve time: 0.06s
# Presolved: 3806 rows, 2397 columns, 12265 nonzeros
# Found heuristic solution: objective 601.0000000
# Variable types: 0 continuous, 2397 integer (2397 binary)
#
# Root relaxation: objective 1.154000e+03, 1216 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1154.0000000 1154.00000  0.00%     -    0s
#
# Explored 0 nodes (1216 simplex iterations) in 0.13 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1154 601 148
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.154000000000e+03, best bound 1.154000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25292 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6310 rows and 3157 columns
# Presolve time: 0.06s
# Presolved: 3691 rows, 2343 columns, 11937 nonzeros
# Found heuristic solution: objective 583.0000000
# Variable types: 0 continuous, 2343 integer (2343 binary)
#
# Root relaxation: objective 1.123000e+03, 1236 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1123.0000000 1123.00000  0.00%     -    0s
#
# Explored 0 nodes (1236 simplex iterations) in 0.12 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1123 583 164
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.123000000000e+03, best bound 1.123000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25358 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6442 rows and 3229 columns
# Presolve time: 0.06s
# Presolved: 3559 rows, 2271 columns, 11552 nonzeros
# Found heuristic solution: objective 666.0000000
# Variable types: 0 continuous, 2271 integer (2271 binary)
#
# Root relaxation: objective 1.131000e+03, 1233 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1131.0000000 1131.00000  0.00%     -    0s
#
# Explored 0 nodes (1233 simplex iterations) in 0.12 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1131 666 302
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.131000000000e+03, best bound 1.131000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25536 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6321 rows and 3173 columns
# Presolve time: 0.06s
# Presolved: 3680 rows, 2327 columns, 11933 nonzeros
# Found heuristic solution: objective 657.0000000
# Variable types: 0 continuous, 2327 integer (2326 binary)
#
# Root relaxation: objective 1.178000e+03, 1209 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1178.0000000 1178.00000  0.00%     -    0s
#
# Explored 0 nodes (1209 simplex iterations) in 0.12 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1178 657 297
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.178000000000e+03, best bound 1.178000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25176 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6407 rows and 3206 columns
# Presolve time: 0.06s
# Presolved: 3594 rows, 2294 columns, 11606 nonzeros
# Found heuristic solution: objective 617.0000000
# Variable types: 0 continuous, 2294 integer (2293 binary)
#
# Root relaxation: objective 1.068000e+03, 1289 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1068.0000000 1068.00000  0.00%     -    0s
#
# Explored 0 nodes (1289 simplex iterations) in 0.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1068 617 199
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.068000000000e+03, best bound 1.068000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25230 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6344 rows and 3175 columns
# Presolve time: 0.05s
# Presolved: 3657 rows, 2325 columns, 11795 nonzeros
# Found heuristic solution: objective 618.0000000
# Variable types: 0 continuous, 2325 integer (2324 binary)
#
# Root relaxation: objective 1.171000e+03, 1163 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1171.0000000 1171.00000  0.00%     -    0s
#
# Explored 0 nodes (1163 simplex iterations) in 0.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1171 618 193
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.171000000000e+03, best bound 1.171000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25394 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6210 rows and 3107 columns
# Presolve time: 0.05s
# Presolved: 3791 rows, 2393 columns, 12235 nonzeros
# Found heuristic solution: objective 603.0000000
# Variable types: 0 continuous, 2393 integer (2393 binary)
#
# Root relaxation: objective 1.132000e+03, 1284 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1132.0000000 1132.00000  0.00%     -    0s
#
# Explored 0 nodes (1284 simplex iterations) in 0.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1132 603 174
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.132000000000e+03, best bound 1.132000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25468 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6223 rows and 3115 columns
# Presolve time: 0.06s
# Presolved: 3778 rows, 2385 columns, 12237 nonzeros
# Found heuristic solution: objective 617.0000000
# Variable types: 0 continuous, 2385 integer (2385 binary)
#
# Root relaxation: objective 1.150000e+03, 1265 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1150.0000000 1150.00000  0.00%     -    0s
#
# Explored 0 nodes (1265 simplex iterations) in 0.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1150 617 169
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.150000000000e+03, best bound 1.150000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25520 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 7428 rows and 3748 columns
# Presolve time: 0.06s
# Presolved: 2573 rows, 1752 columns, 8617 nonzeros
# Found heuristic solution: objective 649.0000000
# Variable types: 0 continuous, 1752 integer (1752 binary)
#
# Root relaxation: objective 1.180500e+03, 740 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1180.50000    0   21  649.00000 1180.50000  81.9%     -    0s
# H    0     0                    1180.0000000 1180.50000  0.04%     -    0s
#
# Explored 1 nodes (756 simplex iterations) in 0.12 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1180 649 306
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.180000000000e+03, best bound 1.180000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25440 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 7416 rows and 3734 columns
# Presolve time: 0.06s
# Presolved: 2585 rows, 1766 columns, 8620 nonzeros
# Found heuristic solution: objective 648.0000000
# Variable types: 0 continuous, 1766 integer (1766 binary)
#
# Root relaxation: objective 1.191000e+03, 725 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1191.0000000 1191.00000  0.00%     -    0s
#
# Explored 0 nodes (749 simplex iterations) in 0.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1191 648 293
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.191000000000e+03, best bound 1.191000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25482 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6172 rows and 3093 columns
# Presolve time: 0.06s
# Presolved: 3829 rows, 2407 columns, 12311 nonzeros
# Found heuristic solution: objective 668.0000000
# Variable types: 0 continuous, 2407 integer (2406 binary)
#
# Root relaxation: objective 1.211000e+03, 1274 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1211.0000000 1211.00000  0.00%     -    0s
#
# Explored 0 nodes (1274 simplex iterations) in 0.12 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1211 668 181
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.211000000000e+03, best bound 1.211000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25282 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 7588 rows and 3843 columns
# Presolve time: 0.06s
# Presolved: 2413 rows, 1657 columns, 8047 nonzeros
# Found heuristic solution: objective 624.0000000
# Variable types: 0 continuous, 1657 integer (1656 binary)
#
# Root relaxation: objective 1.158000e+03, 676 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1158.0000000 1158.00000  0.00%     -    0s
#
# Explored 0 nodes (676 simplex iterations) in 0.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1158 624 254
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.158000000000e+03, best bound 1.158000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25466 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6284 rows and 3152 columns
# Presolve time: 0.06s
# Presolved: 3717 rows, 2348 columns, 12003 nonzeros
# Found heuristic solution: objective 641.0000000
# Variable types: 0 continuous, 2348 integer (2348 binary)
#
# Root relaxation: objective 1.168500e+03, 1304 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1168.50000    0   30  641.00000 1168.50000  82.3%     -    0s
# H    0     0                    1168.0000000 1168.50000  0.04%     -    0s
#
# Explored 1 nodes (1341 simplex iterations) in 0.13 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1168 641 255
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.168000000000e+03, best bound 1.168000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25528 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 7486 rows and 3788 columns
# Presolve time: 0.07s
# Presolved: 2515 rows, 1712 columns, 8395 nonzeros
# Found heuristic solution: objective 652.0000000
# Variable types: 0 continuous, 1712 integer (1711 binary)
#
# Root relaxation: objective 1.199000e+03, 804 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1199.0000000 1199.00000  0.00%     -    0s
#
# Explored 0 nodes (804 simplex iterations) in 0.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1199 652 330
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.199000000000e+03, best bound 1.199000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25414 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 7541 rows and 3812 columns
# Presolve time: 0.07s
# Presolved: 2460 rows, 1688 columns, 8164 nonzeros
# Found heuristic solution: objective 698.0000000
# Variable types: 0 continuous, 1688 integer (1687 binary)
#
# Root relaxation: objective 1.139000e+03, 806 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# *    0     0               0    1139.0000000 1139.00000  0.00%     -    0s
#
# Explored 0 nodes (806 simplex iterations) in 0.12 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1139 698 294
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.139000000000e+03, best bound 1.139000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25304 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 7423 rows and 3735 columns
# Presolve time: 0.07s
# Presolved: 2578 rows, 1765 columns, 8595 nonzeros
# Found heuristic solution: objective 584.0000000
# Variable types: 0 continuous, 1765 integer (1765 binary)
#
# Root relaxation: objective 1.099000e+03, 726 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1099.0000000 1099.00000  0.00%     -    0s
#
# Explored 0 nodes (726 simplex iterations) in 0.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1099 584 171
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.099000000000e+03, best bound 1.099000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25250 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6239 rows and 3121 columns
# Presolve time: 0.05s
# Presolved: 3762 rows, 2379 columns, 12095 nonzeros
# Found heuristic solution: objective 599.0000000
# Variable types: 0 continuous, 2379 integer (2379 binary)
#
# Root relaxation: objective 1.123000e+03, 1292 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1123.0000000 1123.00000  0.00%     -    0s
#
# Explored 0 nodes (1292 simplex iterations) in 0.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1123 599 171
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.123000000000e+03, best bound 1.123000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25310 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6502 rows and 3257 columns
# Presolve time: 0.06s
# Presolved: 3499 rows, 2243 columns, 11354 nonzeros
# Found heuristic solution: objective 637.0000000
# Variable types: 0 continuous, 2243 integer (2243 binary)
#
# Root relaxation: objective 1.108000e+03, 1216 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1108.0000000 1108.00000  0.00%     -    0s
#
# Explored 0 nodes (1216 simplex iterations) in 0.12 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1108 637 307
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.108000000000e+03, best bound 1.108000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25392 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 7394 rows and 3735 columns
# Presolve time: 0.06s
# Presolved: 2607 rows, 1765 columns, 8670 nonzeros
# Found heuristic solution: objective 699.0000000
# Variable types: 0 continuous, 1765 integer (1764 binary)
#
# Root relaxation: objective 1.199000e+03, 670 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1199.0000000 1199.00000  0.00%     -    0s
#
# Explored 0 nodes (670 simplex iterations) in 0.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1199 699 291
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.199000000000e+03, best bound 1.199000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25298 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 7598 rows and 3834 columns
# Presolve time: 0.06s
# Presolved: 2403 rows, 1666 columns, 8039 nonzeros
# Found heuristic solution: objective 656.0000000
# Variable types: 0 continuous, 1666 integer (1666 binary)
#
# Root relaxation: objective 1.159000e+03, 687 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1159.0000000 1159.00000  0.00%     -    0s
#
# Explored 0 nodes (687 simplex iterations) in 0.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1159 656 315
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.159000000000e+03, best bound 1.159000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25178 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6377 rows and 3191 columns
# Presolve time: 0.05s
# Presolved: 3624 rows, 2309 columns, 11665 nonzeros
# Found heuristic solution: objective 618.0000000
# Variable types: 0 continuous, 2309 integer (2309 binary)
#
# Root relaxation: objective 1.116500e+03, 1247 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 1116.50000    0   53  618.00000 1116.50000  80.7%     -    0s
# H    0     0                    1116.0000000 1116.50000  0.04%     -    0s
#
# Explored 1 nodes (1262 simplex iterations) in 0.12 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1116 618 168
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.116000000000e+03, best bound 1.116000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25424 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 6e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 7451 rows and 3755 columns
# Presolve time: 0.07s
# Presolved: 2550 rows, 1745 columns, 8518 nonzeros
# Found heuristic solution: objective 646.0000000
# Variable types: 0 continuous, 1745 integer (1745 binary)
#
# Root relaxation: objective 1.128000e+03, 831 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1128.0000000 1128.00000  0.00%     -    0s
#
# Explored 0 nodes (831 simplex iterations) in 0.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1128 646 263
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.128000000000e+03, best bound 1.128000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25278 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 6289 rows and 3151 columns
# Presolve time: 0.06s
# Presolved: 3712 rows, 2349 columns, 12029 nonzeros
# Found heuristic solution: objective 613.0000000
# Variable types: 0 continuous, 2349 integer (2347 binary)
#
# Root relaxation: objective 1.088000e+03, 1311 iterations, 0.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1088.0000000 1088.00000  0.00%     -    0s
#
# Explored 0 nodes (1311 simplex iterations) in 0.12 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1088 613 156
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.088000000000e+03, best bound 1.088000000000e+03, gap 0.0000%
# Optimize a model with 10001 rows, 5500 columns and 25272 nonzeros
# Variable types: 0 continuous, 5500 integer (5500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 5e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 2e+01]
# Found heuristic solution: objective -0.0000000
# Presolve removed 7640 rows and 3852 columns
# Presolve time: 0.06s
# Presolved: 2361 rows, 1648 columns, 7870 nonzeros
# Found heuristic solution: objective 657.0000000
# Variable types: 0 continuous, 1648 integer (1648 binary)
#
# Root relaxation: objective 1.128000e+03, 707 iterations, 0.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1128.0000000 1128.00000  0.00%     -    0s
#
# Explored 0 nodes (707 simplex iterations) in 0.11 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 1128 657 293
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.128000000000e+03, best bound 1.128000000000e+03, gap 0.0000%
