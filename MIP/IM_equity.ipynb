# %%
from __future__ import print_function, division
from gurobipy import Model, GRB, quicksum, LinExpr
import networkx as nx
import pickle
import numpy, random

# %%
def MIP_IM():
    budget = 25
    m = 100
    epsilon = 1
    
    attributes = ['gender','age', 'region', 'ethnicity']
  
    for attribute in attributes:
        for index in range(20):
            with open('../MIP/data/networks_prob/graph_spa_500_'+str(index)+'.pickle', "rb") as f:
                main_graph = pickle.load(f)

                samples = []
                for j in range(m):
                    G = nx.DiGraph()
                    for u in main_graph.nodes():
                        G.add_node(u)
                    for u,v in main_graph.edges():
                        if main_graph[u][v]['p']> random.random():
                            G.add_edge(u, v)
                    samples.append(G)


                model = Model('fairseed_'+str(index))

                mvars = []
                #active nodes
                avars = []
                #seed nodes
                svars = []
                var_seed_dict = {}
                var_active_dict = {}
                var_mean_dict = {}

                for j in range(len(main_graph.nodes())):
                    s = model.addVar(lb=0.0, ub=1.0, vtype=GRB.BINARY)
                    svars.append(s)
                    var_seed_dict[j] = s

                for sample_index, sample in enumerate(samples):
                    for j in range(len(main_graph.nodes())):
                        a = model.addVar(lb=0.0, ub=1.0, vtype=GRB.BINARY)
                        avars.append(a)
                        var_active_dict[(sample_index,j)] = a    

                mvars.append(avars)
                mvars.append(svars)

                obj_expr = quicksum(avars)
                model.setObjective(obj_expr, GRB.MAXIMIZE)
                model.addConstr(quicksum(svars), GRB.LESS_EQUAL, budget)

                for sample_index, sample in enumerate(samples):
                    for i in range(len(main_graph.nodes())):
                        neighbors = nx.ancestors(sample, i) 
                        e = len(neighbors)
                        ai = var_active_dict[(sample_index,i)]
                        si = var_seed_dict[i]
                        neighbors_active_vars = []
                        neighbors_seed_vars = []
                        neighbors_active_vars.append(((e+1), ai))
                        neighbors_seed_vars.append(si)
                        for neighbor in neighbors:
                            neighbors_active_vars.append(((e+1), var_active_dict[(sample_index,neighbor)]))
                            neighbors_seed_vars.append(var_seed_dict[neighbor])
                        seed_neighbors = quicksum(neighbors_seed_vars)
                        model.addConstr(ai, GRB.LESS_EQUAL, seed_neighbors)
                        model.addConstr(seed_neighbors, GRB.LESS_EQUAL, LinExpr(neighbors_active_vars))


                labels = nx.get_node_attributes(main_graph, attribute)
                label_dict = {}
                for i in range(len(main_graph.nodes())):
                    label = labels[i].encode('utf-8')
                    if label in label_dict.keys():
                        label_dict[label].append(i)
                    else:
                        label_dict[label] = [i]     

                for label in label_dict.keys():
                    seed_vars = []
                    label_size = len(label_dict[label])
                    frac = float(label_size)/float(len(main_graph.nodes()))
                    for node in label_dict[label]:
                        seed_vars.append(var_seed_dict[node])
                    label_budget = budget*frac
                    expr = quicksum(seed_vars)
                    model.addConstr(expr, GRB.LESS_EQUAL, label_budget+ epsilon)
                    model.addConstr(expr, GRB.GREATER_EQUAL, label_budget-epsilon)    
                    

                try:
                    model.optimize()
                except e:
                    print(e)
                with open('../../../../Git/influence_maximization/experiments/im500/results/fairmip/fairseed/base100/'+attribute+'/output_'+str(index)+'.txt', "w") as of:    
                    for key,value in var_seed_dict.items():
                        if(value.x > 0):
                            print(key, file=of)

# %%
MIP_IM()
# Out:
# Optimize a model with 100005 rows, 50500 columns and 311699 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59653 rows and 29010 columns
# Presolve time: 1.07s
# Presolved: 40352 rows, 21490 columns, 165141 nonzeros
# Variable types: 0 continuous, 21490 integer (21490 binary)
# Found heuristic solution: objective 7698.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40350 rows, 21492 columns, 164643 nonzeros
#
# Concurrent spin time: 0.53s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.911000e+03, 31776 iterations, 3.45 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7911.0000000 7911.00000  0.00%     -    4s
#
# Explored 0 nodes (31776 simplex iterations) in 4.98 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7911 7698
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.911000000000e+03, best bound 7.911000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 310376 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59483 rows and 28926 columns
# Presolve time: 1.02s
# Presolved: 40522 rows, 21574 columns, 164373 nonzeros
# Variable types: 0 continuous, 21574 integer (21574 binary)
# Found heuristic solution: objective 7237.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40520 rows, 21576 columns, 163875 nonzeros
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.652000e+03, 32095 iterations, 3.25 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7652.0000000 7652.00000  0.00%     -    4s
#
# Explored 0 nodes (32095 simplex iterations) in 4.86 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7652 7237
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.652000000000e+03, best bound 7.652000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 311954 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 58774 rows and 28501 columns
# Presolve time: 1.03s
# Presolved: 41231 rows, 21999 columns, 167037 nonzeros
# Variable types: 0 continuous, 21999 integer (21999 binary)
# Found heuristic solution: objective 7495.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 41229 rows, 22001 columns, 166539 nonzeros
#
# Concurrent spin time: 0.55s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.637000e+03, 31277 iterations, 3.09 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7637.0000000 7637.00000  0.00%     -    4s
#
# Explored 0 nodes (31277 simplex iterations) in 4.73 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7637 7495
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.637000000000e+03, best bound 7.637000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 311774 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59231 rows and 28785 columns
# Presolve time: 1.02s
# Presolved: 40774 rows, 21715 columns, 166036 nonzeros
# Variable types: 0 continuous, 21715 integer (21715 binary)
# Found heuristic solution: objective 7423.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40772 rows, 21717 columns, 165538 nonzeros
#
# Concurrent spin time: 0.71s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.792000e+03, 32923 iterations, 3.21 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7792.0000000 7792.00000  0.00%     -    4s
#
# Explored 0 nodes (32923 simplex iterations) in 4.75 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7792 7423
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.792000000000e+03, best bound 7.792000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 308741 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 60002 rows and 29169 columns
# Presolve time: 0.99s
# Presolved: 40003 rows, 21331 columns, 162011 nonzeros
# Variable types: 0 continuous, 21331 integer (21331 binary)
# Found heuristic solution: objective 7250.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40001 rows, 21333 columns, 161513 nonzeros
#
# Concurrent spin time: 0.39s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.539000e+03, 29609 iterations, 2.66 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7539.0000000 7539.00000  0.00%     -    4s
#
# Explored 0 nodes (29609 simplex iterations) in 4.47 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7539 7250
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.539000000000e+03, best bound 7.539000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 313883 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 58896 rows and 28597 columns
# Presolve time: 1.05s
# Presolved: 41109 rows, 21903 columns, 168261 nonzeros
# Variable types: 0 continuous, 21903 integer (21903 binary)
# Found heuristic solution: objective 8289.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 41107 rows, 21905 columns, 167763 nonzeros
#
# Concurrent spin time: 1.02s
#
# Solved with dual simplex
#
# Root relaxation: objective 8.501000e+03, 32285 iterations, 3.18 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8501.0000000 8501.00000  0.00%     -    4s
#
# Explored 0 nodes (32285 simplex iterations) in 4.84 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 8501 8289
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.501000000000e+03, best bound 8.501000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 310154 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59098 rows and 28719 columns
# Presolve time: 1.03s
# Presolved: 40907 rows, 21781 columns, 164669 nonzeros
# Variable types: 0 continuous, 21781 integer (21781 binary)
# Found heuristic solution: objective 7531.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40905 rows, 21783 columns, 164171 nonzeros
#
# Concurrent spin time: 0.01s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.715000e+03, 29919 iterations, 2.91 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7715.0000000 7715.00000  0.00%     -    4s
#
# Explored 0 nodes (29929 simplex iterations) in 4.71 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7715 7531
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.715000000000e+03, best bound 7.715000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 310946 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59450 rows and 28924 columns
# Presolve time: 1.02s
# Presolved: 40555 rows, 21576 columns, 164643 nonzeros
# Variable types: 0 continuous, 21576 integer (21576 binary)
# Found heuristic solution: objective 7606.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40553 rows, 21578 columns, 164145 nonzeros
#
# Concurrent spin time: 0.61s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.732000e+03, 33950 iterations, 3.38 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7732.0000000 7732.00000  0.00%     -    5s
#
# Explored 0 nodes (33950 simplex iterations) in 5.22 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7732 7606
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.732000000000e+03, best bound 7.732000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 309818 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59054 rows and 28760 columns
# Presolve time: 1.07s
# Presolved: 40951 rows, 21740 columns, 164750 nonzeros
# Variable types: 0 continuous, 21740 integer (21740 binary)
# Found heuristic solution: objective 7438.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40949 rows, 21742 columns, 164252 nonzeros
#
# Concurrent spin time: 0.49s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.786000e+03, 32407 iterations, 3.11 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7786.0000000 7786.00000  0.00%     -    4s
#
# Explored 0 nodes (32407 simplex iterations) in 4.89 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7786 7438
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.786000000000e+03, best bound 7.786000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 310328 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59574 rows and 28971 columns
# Presolve time: 1.09s
# Presolved: 40431 rows, 21529 columns, 164145 nonzeros
# Variable types: 0 continuous, 21529 integer (21529 binary)
# Found heuristic solution: objective 7474.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40429 rows, 21531 columns, 163647 nonzeros
#
# Concurrent spin time: 1.05s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.632000e+03, 31540 iterations, 2.96 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7632.0000000 7632.00000  0.00%     -    4s
#
# Explored 0 nodes (31540 simplex iterations) in 4.63 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7632 7474
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.632000000000e+03, best bound 7.632000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 308681 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59464 rows and 28931 columns
# Presolve time: 0.87s
# Presolved: 40541 rows, 21569 columns, 163024 nonzeros
# Variable types: 0 continuous, 21569 integer (21569 binary)
# Found heuristic solution: objective 7758.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40539 rows, 21571 columns, 162526 nonzeros
#
# Concurrent spin time: 0.81s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.879000e+03, 30886 iterations, 2.95 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7879.0000000 7879.00000  0.00%     -    4s
#
# Explored 0 nodes (30886 simplex iterations) in 4.33 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7879 7758
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.879000000000e+03, best bound 7.879000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 311288 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59340 rows and 28838 columns
# Presolve time: 1.11s
# Presolved: 40665 rows, 21662 columns, 165403 nonzeros
# Variable types: 0 continuous, 21662 integer (21662 binary)
# Found heuristic solution: objective 7996.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40663 rows, 21664 columns, 164905 nonzeros
#
# Concurrent spin time: 0.59s
#
# Solved with dual simplex
#
# Root relaxation: objective 8.250000e+03, 30032 iterations, 3.08 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8250.0000000 8250.00000  0.00%     -    4s
#
# Explored 0 nodes (30032 simplex iterations) in 4.61 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 8250 7996
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.250000000000e+03, best bound 8.250000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 310895 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59728 rows and 29075 columns
# Presolve time: 1.06s
# Presolved: 40277 rows, 21425 columns, 164430 nonzeros
# Variable types: 0 continuous, 21425 integer (21425 binary)
# Found heuristic solution: objective 7524.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40275 rows, 21427 columns, 163932 nonzeros
#
# Concurrent spin time: 0.93s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.680000e+03, 33717 iterations, 3.31 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7680.0000000 7680.00000  0.00%     -    5s
#
# Explored 0 nodes (33717 simplex iterations) in 5.20 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7680 7524
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.680000000000e+03, best bound 7.680000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 310820 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59139 rows and 28667 columns
# Presolve time: 1.02s
# Presolved: 40866 rows, 21833 columns, 164982 nonzeros
# Variable types: 0 continuous, 21833 integer (21833 binary)
# Found heuristic solution: objective 7120.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40864 rows, 21835 columns, 164484 nonzeros
#
# Concurrent spin time: 1.16s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.376000e+03, 32857 iterations, 3.15 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7376.0000000 7376.00000  0.00%     -    4s
#
# Explored 0 nodes (32857 simplex iterations) in 4.84 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7376 7120
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.376000000000e+03, best bound 7.376000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 311759 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59185 rows and 28702 columns
# Presolve time: 1.06s
# Presolved: 40820 rows, 21798 columns, 166065 nonzeros
# Variable types: 0 continuous, 21798 integer (21798 binary)
# Found heuristic solution: objective 7808.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40818 rows, 21800 columns, 165567 nonzeros
#
# Concurrent spin time: 0.69s
#
# Solved with dual simplex
#
# Root relaxation: objective 8.016000e+03, 32474 iterations, 3.05 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8016.0000000 8016.00000  0.00%     -    4s
#
# Explored 0 nodes (32474 simplex iterations) in 4.83 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 8016 7808
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.016000000000e+03, best bound 8.016000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 310622 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59229 rows and 28769 columns
# Presolve time: 1.02s
# Presolved: 40776 rows, 21731 columns, 164964 nonzeros
# Variable types: 0 continuous, 21731 integer (21731 binary)
# Found heuristic solution: objective 7283.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40774 rows, 21733 columns, 164466 nonzeros
#
# Concurrent spin time: 1.25s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.546000e+03, 33943 iterations, 3.35 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7546.0000000 7546.00000  0.00%     -    4s
#
# Explored 0 nodes (33943 simplex iterations) in 5.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7546 7283
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.546000000000e+03, best bound 7.546000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 311204 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59031 rows and 28678 columns
# Presolve time: 1.05s
# Presolved: 40974 rows, 21822 columns, 165943 nonzeros
# Variable types: 0 continuous, 21822 integer (21822 binary)
# Found heuristic solution: objective 7683.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40972 rows, 21824 columns, 165445 nonzeros
#
# Concurrent spin time: 0.46s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.913000e+03, 31221 iterations, 3.06 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7913.0000000 7913.00000  0.00%     -    4s
#
# Explored 0 nodes (31221 simplex iterations) in 4.69 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7913 7683
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.913000000000e+03, best bound 7.913000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 310937 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59540 rows and 28952 columns
# Presolve time: 1.00s
# Presolved: 40465 rows, 21548 columns, 164748 nonzeros
# Variable types: 0 continuous, 21548 integer (21548 binary)
# Found heuristic solution: objective 7382.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40463 rows, 21550 columns, 164250 nonzeros
#
# Concurrent spin time: 0.84s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.616000e+03, 32456 iterations, 3.24 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7616.00000    0  695 7382.00000 7616.00000  3.17%     -    4s
# H    0     0                    7611.0000000 7616.00000  0.07%     -    4s
# *    0     0               0    7616.0000000 7616.00000  0.00%     -    5s
#      0     0          -    0      7616.00000 7616.00000  0.00%     -    5s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 1
#
# Explored 1 nodes (32488 simplex iterations) in 5.17 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 7616 7611 7382
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.616000000000e+03, best bound 7.616000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 312218 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59246 rows and 28727 columns
# Presolve time: 1.02s
# Presolved: 40759 rows, 21773 columns, 166049 nonzeros
# Variable types: 0 continuous, 21773 integer (21773 binary)
# Found heuristic solution: objective 7301.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40757 rows, 21775 columns, 165551 nonzeros
# Concurrent spin time: 0.70s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.457000e+03, 31391 iterations, 3.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7457.0000000 7457.00000  0.00%     -    4s
#
# Explored 0 nodes (31391 simplex iterations) in 4.69 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7457 7301
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.457000000000e+03, best bound 7.457000000000e+03, gap 0.0000%
# Optimize a model with 100005 rows, 50500 columns and 312446 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 2e+01]
# Presolve removed 59017 rows and 28628 columns
# Presolve time: 1.06s
# Presolved: 40988 rows, 21872 columns, 166970 nonzeros
# Variable types: 0 continuous, 21872 integer (21872 binary)
# Found heuristic solution: objective 7607.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 2 rows and 0 columns
# Presolved: 40986 rows, 21874 columns, 166472 nonzeros
#
# Concurrent spin time: 0.11s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.905000e+03, 29715 iterations, 2.87 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7905.0000000 7905.00000  0.00%     -    4s
#
# Explored 0 nodes (29715 simplex iterations) in 4.83 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7905 7607
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.905000000000e+03, best bound 7.905000000000e+03, gap 0.0000%
# Optimize a model with 100015 rows, 50500 columns and 311978 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 2e+01]
# Presolve removed 59289 rows and 28831 columns
# Presolve time: 1.03s
# Presolved: 40726 rows, 21669 columns, 165784 nonzeros
# Variable types: 0 continuous, 21669 integer (21669 binary)
# Found heuristic solution: objective 7521.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 7 rows and 0 columns
# Presolved: 40719 rows, 21676 columns, 165291 nonzeros
#
# Concurrent spin time: 0.04s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.810000e+03, 32077 iterations, 3.31 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7810.00000    0 1430 7521.00000 7810.00000  3.84%     -    4s
# H    0     0                    7541.0000000 7810.00000  3.57%     -    5s
# H    0     0                    7733.0000000 7810.00000  1.00%     -    5s
#      0     0 7808.33333    0 1824 7733.00000 7808.33333  0.97%     -    5s
# H    0     0                    7801.0000000 7808.33333  0.09%     -    5s
# H    0     0                    7805.0000000 7808.33333  0.04%     -    5s
# H    0     0                    7806.0000000 7808.33333  0.03%     -    5s
#      0     0 7807.00000    0 1828 7806.00000 7807.00000  0.01%     -    5s
#      0     0 7807.00000    0   43 7806.00000 7807.00000  0.01%     -    6s
#      0     0 7807.00000    0   46 7806.00000 7807.00000  0.01%     -    6s
#      0     0 7807.00000    0   13 7806.00000 7807.00000  0.01%     -    6s
#
# Explored 1 nodes (32540 simplex iterations) in 6.12 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 6: 7806 7805 7801 ... 7521
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.806000000000e+03, best bound 7.806000000000e+03, gap 0.0000%
# Optimize a model with 100015 rows, 50500 columns and 311438 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e-01, 2e+01]
# Presolve removed 59569 rows and 28953 columns
# Presolve time: 1.04s
# Presolved: 40446 rows, 21547 columns, 164766 nonzeros
# Variable types: 0 continuous, 21547 integer (21547 binary)
# Found heuristic solution: objective 7409.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 7 rows and 0 columns
# Presolved: 40439 rows, 21554 columns, 164273 nonzeros
#
# Concurrent spin time: 0.32s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.815000e+03, 30876 iterations, 3.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7815.0000000 7815.00000  0.00%     -    4s
#
# Explored 0 nodes (30876 simplex iterations) in 5.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7815 7409
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.815000000000e+03, best bound 7.815000000000e+03, gap 0.0000%
# Optimize a model with 100015 rows, 50500 columns and 311138 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e-01, 2e+01]
# Presolve removed 59433 rows and 28860 columns
# Presolve time: 1.02s
# Presolved: 40582 rows, 21640 columns, 164850 nonzeros
# Variable types: 0 continuous, 21640 integer (21640 binary)
# Found heuristic solution: objective 7446.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 7 rows and 0 columns
# Presolved: 40575 rows, 21647 columns, 164357 nonzeros
#
# Concurrent spin time: 0.77s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.594000e+03, 31546 iterations, 2.87 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7594.0000000 7594.00000  0.00%     -    4s
#
# Explored 0 nodes (31546 simplex iterations) in 4.31 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7594 7446
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.594000000000e+03, best bound 7.594000000000e+03, gap 0.0000%
# Optimize a model with 100015 rows, 50500 columns and 311624 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [7e-01, 2e+01]
# Presolve removed 59576 rows and 28909 columns
# Presolve time: 1.02s
# Presolved: 40439 rows, 21591 columns, 164593 nonzeros
# Variable types: 0 continuous, 21591 integer (21591 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 7 rows and 0 columns
# Presolved: 40432 rows, 21598 columns, 164100 nonzeros
#
# Concurrent spin time: 0.72s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.607000e+03, 31795 iterations, 3.01 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7607.0000000 7607.00000  0.00%     -    5s
#
# Explored 0 nodes (31795 simplex iterations) in 5.14 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 7607
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.607000000000e+03, best bound 7.607000000000e+03, gap 0.0000%
# Optimize a model with 100015 rows, 50500 columns and 309179 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [6e-01, 2e+01]
# Presolve removed 60077 rows and 29206 columns
# Presolve time: 1.05s
# Presolved: 39938 rows, 21294 columns, 162149 nonzeros
# Variable types: 0 continuous, 21294 integer (21294 binary)
# Found heuristic solution: objective 7259.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 7 rows and 0 columns
# Presolved: 39931 rows, 21301 columns, 161656 nonzeros
#
# Concurrent spin time: 0.25s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.637000e+03, 31413 iterations, 2.81 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7637.0000000 7637.00000  0.00%     -    4s
#
# Explored 0 nodes (31413 simplex iterations) in 4.84 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7637 7259
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.637000000000e+03, best bound 7.637000000000e+03, gap 0.0000%
# Optimize a model with 100015 rows, 50500 columns and 311258 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 2e+01]
# Presolve removed 59109 rows and 28710 columns
# Presolve time: 1.01s
# Presolved: 40906 rows, 21790 columns, 165791 nonzeros
# Variable types: 0 continuous, 21790 integer (21790 binary)
# Found heuristic solution: objective 5181.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 7 rows and 0 columns
# Presolved: 40899 rows, 21797 columns, 165298 nonzeros
#
# Concurrent spin time: 0.35s
#
# Solved with dual simplex
#
# Root relaxation: objective 8.346000e+03, 30285 iterations, 3.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8346.0000000 8346.00000  0.00%     -    4s
#
# Explored 0 nodes (30285 simplex iterations) in 4.89 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 8346 5181
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.346000000000e+03, best bound 8.346000000000e+03, gap 0.0000%
# Optimize a model with 100015 rows, 50500 columns and 312134 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e-01, 2e+01]
# Presolve removed 58849 rows and 28581 columns
# Presolve time: 1.05s
# Presolved: 41166 rows, 21919 columns, 166835 nonzeros
# Variable types: 0 continuous, 21919 integer (21919 binary)
# Found heuristic solution: objective 5006.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 7 rows and 0 columns
# Presolved: 41159 rows, 21926 columns, 166342 nonzeros
#
# Concurrent spin time: 0.07s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.826500e+03, 33046 iterations, 3.23 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7826.50000    0  935 5006.00000 7826.50000  56.3%     -    5s
# H    0     0                    7627.0000000 7826.50000  2.62%     -    5s
# H    0     0                    7821.0000000 7826.50000  0.07%     -    5s
#      0     0 7826.00000    0  936 7821.00000 7826.00000  0.06%     -    5s
#      0     0 7826.00000    0   86 7821.00000 7826.00000  0.06%     -    5s
#
# Explored 1 nodes (33541 simplex iterations) in 5.87 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 7821 7627 5006
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.821000000000e+03, best bound 7.821000000000e+03, gap 0.0000%
# Optimize a model with 100015 rows, 50500 columns and 311762 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [7e-01, 2e+01]
# Presolve removed 59624 rows and 29010 columns
# Presolve time: 1.03s
# Presolved: 40391 rows, 21490 columns, 165204 nonzeros
# Variable types: 0 continuous, 21490 integer (21490 binary)
# Found heuristic solution: objective 7693.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 7 rows and 0 columns
# Presolved: 40384 rows, 21497 columns, 164711 nonzeros
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.770000e+03, 31816 iterations, 3.04 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7770.0000000 7770.00000  0.00%     -    4s
#
# Explored 0 nodes (31816 simplex iterations) in 4.50 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7770 7693
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.770000000000e+03, best bound 7.770000000000e+03, gap 0.0000%
# Optimize a model with 100015 rows, 50500 columns and 311918 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e-01, 2e+01]
# Presolve removed 59052 rows and 28727 columns
# Presolve time: 0.91s
# Presolved: 40963 rows, 21773 columns, 166770 nonzeros
# Variable types: 0 continuous, 21773 integer (21773 binary)
# Found heuristic solution: objective 7371.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 7 rows and 0 columns
# Presolved: 40956 rows, 21780 columns, 166277 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    34075    7.7610000e+03   0.000000e+00   0.000000e+00      5s
# Concurrent spin time: 0.39s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.761000e+03, 32505 iterations, 3.43 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7761.0000000 7761.00000  0.00%     -    5s
#
# Explored 0 nodes (32505 simplex iterations) in 5.48 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7761 7371
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.761000000000e+03, best bound 7.761000000000e+03, gap 0.0000%
# Optimize a model with 100015 rows, 50500 columns and 311420 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e-01, 2e+01]
# Presolve removed 59246 rows and 28772 columns
# Presolve time: 1.03s
# Presolved: 40769 rows, 21728 columns, 165585 nonzeros
# Variable types: 0 continuous, 21728 integer (21728 binary)
# Found heuristic solution: objective 7520.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 7 rows and 0 columns
# Presolved: 40762 rows, 21735 columns, 165092 nonzeros
#
# Concurrent spin time: 0.71s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.694000e+03, 30860 iterations, 2.79 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7694.0000000 7694.00000  0.00%     -    4s
#
# Explored 0 nodes (30860 simplex iterations) in 4.32 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7694 7520
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.694000000000e+03, best bound 7.694000000000e+03, gap 0.0000%
# Optimize a model with 100015 rows, 50500 columns and 308030 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [6e-01, 2e+01]
# Presolve removed 59641 rows and 29013 columns
# Presolve time: 1.03s
# Presolved: 40374 rows, 21487 columns, 161889 nonzeros
# Variable types: 0 continuous, 21487 integer (21487 binary)
# Found heuristic solution: objective 7762.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 7 rows and 0 columns
# Presolved: 40367 rows, 21494 columns, 161396 nonzeros
#
# Concurrent spin time: 0.49s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.926000e+03, 31809 iterations, 2.87 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7926.0000000 7926.00000  0.00%     -    4s
#
# Explored 0 nodes (31809 simplex iterations) in 4.59 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7926 7762
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.926000000000e+03, best bound 7.926000000000e+03, gap 0.0000%
# Optimize a model with 100015 rows, 50500 columns and 312581 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [7e-01, 2e+01]
# Presolve removed 59233 rows and 28794 columns
# Presolve time: 1.09s
# Presolved: 40782 rows, 21706 columns, 166682 nonzeros
# Variable types: 0 continuous, 21706 integer (21706 binary)
# Found heuristic solution: objective 8011.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 7 rows and 0 columns
# Presolved: 40775 rows, 21713 columns, 166189 nonzeros
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root relaxation: objective 8.147000e+03, 32530 iterations, 3.14 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8147.0000000 8147.00000  0.00%     -    4s
#
# Explored 0 nodes (32530 simplex iterations) in 5.03 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 8147 8011
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.147000000000e+03, best bound 8.147000000000e+03, gap 0.0000%
# Optimize a model with 100015 rows, 50500 columns and 311150 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [8e-01, 2e+01]
# Presolve removed 59532 rows and 28962 columns
# Presolve time: 1.06s
# Presolved: 40483 rows, 21538 columns, 164882 nonzeros
# Variable types: 0 continuous, 21538 integer (21538 binary)
# Found heuristic solution: objective 7538.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 7 rows and 0 columns
# Presolved: 40476 rows, 21545 columns, 164389 nonzeros
#
# Concurrent spin time: 0.36s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.597000e+03, 31809 iterations, 3.22 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7597.0000000 7597.00000  0.00%     -    5s
#
# Explored 0 nodes (31809 simplex iterations) in 5.18 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7597 7538
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.597000000000e+03, best bound 7.597000000000e+03, gap 0.0000%
# Optimize a model with 100015 rows, 50500 columns and 309338 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [8e-01, 2e+01]
# Presolve removed 59379 rows and 28839 columns
# Presolve time: 1.03s
# Presolved: 40636 rows, 21661 columns, 163665 nonzeros
# Variable types: 0 continuous, 21661 integer (21661 binary)
# Found heuristic solution: objective 7313.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 7 rows and 0 columns
# Presolved: 40629 rows, 21668 columns, 163172 nonzeros
#
# Concurrent spin time: 0.72s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.460500e+03, 30400 iterations, 2.79 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7460.50000    0 1043 7313.00000 7460.50000  2.02%     -    4s
# H    0     0                    7401.0000000 7460.50000  0.80%     -    4s
#      0     0 7459.00000    0 1046 7401.00000 7459.00000  0.78%     -    5s
#      0     0 7459.00000    0  178 7401.00000 7459.00000  0.78%     -    5s
# H    0     0                    7457.0000000 7459.00000  0.03%     -    5s
#      0     0 7458.50000    0  182 7457.00000 7458.50000  0.02%     -    5s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 1
#   Zero half: 6
#
# Explored 1 nodes (34443 simplex iterations) in 5.81 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 7457 7401 7313
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.457000000000e+03, best bound 7.457000000000e+03, gap 0.0000%
# Optimize a model with 100015 rows, 50500 columns and 308912 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [4e-01, 2e+01]
# Presolve removed 59670 rows and 29009 columns
# Presolve time: 0.99s
# Presolved: 40345 rows, 21491 columns, 162704 nonzeros
# Variable types: 0 continuous, 21491 integer (21491 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 7 rows and 0 columns
# Presolved: 40338 rows, 21498 columns, 162211 nonzeros
#
# Concurrent spin time: 0.11s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.680000e+03, 31461 iterations, 2.90 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7680.0000000 7680.00000  0.00%     -    5s
#
# Explored 0 nodes (31461 simplex iterations) in 5.17 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 7680
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.680000000000e+03, best bound 7.680000000000e+03, gap 0.0000%
# Optimize a model with 100015 rows, 50500 columns and 309068 nonzeros
# ...
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7568.0000000 7568.00000  0.00%     -    4s
#
# Explored 0 nodes (29983 simplex iterations) in 4.77 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7568 7324
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.568000000000e+03, best bound 7.568000000000e+03, gap 0.0000%
# Optimize a model with 100011 rows, 50500 columns and 311807 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 2e+01]
# Presolve removed 59031 rows and 28667 columns
# Presolve time: 1.03s
# Presolved: 40980 rows, 21833 columns, 165857 nonzeros
# Variable types: 0 continuous, 21833 integer (21833 binary)
# Found heuristic solution: objective 7438.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 3 rows and 0 columns
# Presolved: 40977 rows, 21836 columns, 165388 nonzeros
#
# Concurrent spin time: 0.72s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.721000e+03, 32998 iterations, 2.99 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7721.0000000 7721.00000  0.00%     -    4s
#
# Explored 0 nodes (32998 simplex iterations) in 4.92 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7721 7438
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.721000000000e+03, best bound 7.721000000000e+03, gap 0.0000%
# Optimize a model with 100011 rows, 50500 columns and 312071 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 2e+01]
# Presolve removed 59007 rows and 28652 columns
# Presolve time: 1.04s
# Presolved: 41004 rows, 21848 columns, 166222 nonzeros
# Variable types: 0 continuous, 21848 integer (21848 binary)
# Found heuristic solution: objective 7763.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 4 rows and 0 columns
# Presolved: 41000 rows, 21852 columns, 165739 nonzeros
#
# Concurrent spin time: 0.47s
#
# Solved with dual simplex
#
# Root relaxation: objective 8.008000e+03, 30975 iterations, 2.81 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8008.0000000 8008.00000  0.00%     -    4s
#
# Explored 0 nodes (30975 simplex iterations) in 4.42 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 8008 7763
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.008000000000e+03, best bound 8.008000000000e+03, gap 0.0000%
# Optimize a model with 100011 rows, 50500 columns and 310976 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-01, 2e+01]
# Presolve removed 59381 rows and 28835 columns
# Presolve time: 1.12s
# Presolved: 40630 rows, 21665 columns, 164707 nonzeros
# Variable types: 0 continuous, 21665 integer (21665 binary)
# Found heuristic solution: objective 7904.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 4 rows and 0 columns
# Presolved: 40626 rows, 21669 columns, 164229 nonzeros
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root relaxation: objective 8.129000e+03, 31126 iterations, 2.85 seconds
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8129.0000000 8129.00000  0.00%     -    4s
#
# Explored 0 nodes (31126 simplex iterations) in 4.73 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 8129 7904
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.129000000000e+03, best bound 8.129000000000e+03, gap 0.0000%
# Optimize a model with 100011 rows, 50500 columns and 312920 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-01, 2e+01]
# Presolve removed 59310 rows and 28805 columns
# Presolve time: 1.11s
# Presolved: 40701 rows, 21695 columns, 166168 nonzeros
# Variable types: 0 continuous, 21695 integer (21695 binary)
# Found heuristic solution: objective 7499.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 3 rows and 0 columns
# Presolved: 40698 rows, 21698 columns, 165704 nonzeros
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.788000e+03, 31731 iterations, 3.10 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7788.0000000 7788.00000  0.00%     -    4s
#
# Explored 0 nodes (31731 simplex iterations) in 4.80 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7788 7499
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.788000000000e+03, best bound 7.788000000000e+03, gap 0.0000%
# Optimize a model with 100011 rows, 50500 columns and 310574 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 2e+01]
# Presolve removed 59043 rows and 28636 columns
# Presolve time: 1.04s
# Presolved: 40968 rows, 21864 columns, 164630 nonzeros
# Variable types: 0 continuous, 21864 integer (21864 binary)
# Found heuristic solution: objective 7288.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 4 rows and 0 columns
# Presolved: 40964 rows, 21868 columns, 164149 nonzeros
#
# Concurrent spin time: 1.04s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.516667e+03, 30783 iterations, 2.79 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7516.66667    0  967 7288.00000 7516.66667  3.14%     -    4s
# H    0     0                    7515.0000000 7516.66667  0.02%     -    5s
# H    0     0                    7516.0000000 7516.66667  0.01%     -    5s
#
# Cutting planes:
#   Zero half: 1
#
# Explored 1 nodes (30835 simplex iterations) in 5.16 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 3: 7516 7515 7288
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.516000000000e+03, best bound 7.516000000000e+03, gap 0.0000%
# Optimize a model with 100011 rows, 50500 columns and 312386 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-01, 2e+01]
# Presolve removed 59148 rows and 28738 columns
# Presolve time: 1.01s
# Presolved: 40863 rows, 21762 columns, 166007 nonzeros
# Variable types: 0 continuous, 21762 integer (21762 binary)
# Found heuristic solution: objective 7600.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 4 rows and 0 columns
# Presolved: 40859 rows, 21766 columns, 165529 nonzeros
#
# Concurrent spin time: 0.38s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.950000e+03, 30066 iterations, 2.85 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7950.0000000 7950.00000  0.00%     -    4s
#
# Explored 0 nodes (30066 simplex iterations) in 4.64 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7950 7600
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.950000000000e+03, best bound 7.950000000000e+03, gap 0.0000%
# Optimize a model with 100011 rows, 50500 columns and 312740 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e-01, 2e+01]
# Presolve removed 58892 rows and 28618 columns
# Presolve time: 1.05s
# Presolved: 41119 rows, 21882 columns, 167372 nonzeros
# Variable types: 0 continuous, 21882 integer (21882 binary)
# Found heuristic solution: objective 7442.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 5 rows and 0 columns
# Presolved: 41114 rows, 21887 columns, 166877 nonzeros
#
# Concurrent spin time: 0.80s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.642000e+03, 32266 iterations, 3.02 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7642.0000000 7642.00000  0.00%     -    4s
#
# Explored 0 nodes (32266 simplex iterations) in 4.89 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7642 7442
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.642000000000e+03, best bound 7.642000000000e+03, gap 0.0000%
# Optimize a model with 100011 rows, 50500 columns and 310370 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-01, 2e+01]
# Presolve removed 59345 rows and 28811 columns
# Presolve time: 1.07s
# Presolved: 40666 rows, 21689 columns, 164435 nonzeros
# Variable types: 0 continuous, 21689 integer (21689 binary)
# Found heuristic solution: objective 7350.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 5 rows and 0 columns
# Presolved: 40661 rows, 21694 columns, 163940 nonzeros
#
# Concurrent spin time: 0.53s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.794000e+03, 33339 iterations, 3.25 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 7794.00000    0  656 7350.00000 7794.00000  6.04%     -    5s
# H    0     0                    7775.0000000 7794.00000  0.24%     -    5s
# H    0     0                    7786.0000000 7794.00000  0.10%     -    5s
#      0     0 7793.00000    0  658 7786.00000 7793.00000  0.09%     -    5s
#      0     0 7793.00000    0   38 7786.00000 7793.00000  0.09%     -    6s
#      0     0 7793.00000    0   40 7786.00000 7793.00000  0.09%     -    6s
#      0     0 7793.00000    0   14 7786.00000 7793.00000  0.09%     -    6s
# H    0     0                    7791.0000000 7793.00000  0.03%     -    6s
#      0     0 7792.00000    0   18 7791.00000 7792.00000  0.01%     -    6s
#
# Cutting planes:
#   Gomory: 1
#   Zero half: 3
#
# Explored 1 nodes (33798 simplex iterations) in 6.04 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 7791 7786 7775 7350
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.791000000000e+03, best bound 7.791000000000e+03, gap 0.0000%
# Optimize a model with 100011 rows, 50500 columns and 310361 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e-02, 2e+01]
# Presolve removed 59604 rows and 28983 columns
# Presolve time: 1.02s
# Presolved: 40407 rows, 21517 columns, 164262 nonzeros
# Variable types: 0 continuous, 21517 integer (21517 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 5 rows and 0 columns
# Presolved: 40402 rows, 21522 columns, 163767 nonzeros
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    34630    7.5690326e+03   0.000000e+00   9.217768e+01      5s
#    34777    7.5810000e+03   0.000000e+00   0.000000e+00      5s
#    34777    7.5810000e+03   0.000000e+00   0.000000e+00      5s
# Concurrent spin time: 0.22s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.581000e+03, 34021 iterations, 3.24 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7581.0000000 7581.00000  0.00%     -    5s
#
# Explored 0 nodes (34021 simplex iterations) in 5.42 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 7581
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.581000000000e+03, best bound 7.581000000000e+03, gap 0.0000%
# Optimize a model with 100011 rows, 50500 columns and 311825 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [5e-02, 2e+01]
# Presolve removed 59601 rows and 28932 columns
# Presolve time: 1.09s
# Presolved: 40410 rows, 21568 columns, 164194 nonzeros
# Variable types: 0 continuous, 21568 integer (21568 binary)
# Found heuristic solution: objective 7163.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 3 rows and 0 columns
# Presolved: 40407 rows, 21571 columns, 163734 nonzeros
#
# Concurrent spin time: 0.02s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.446000e+03, 29736 iterations, 2.75 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7446.0000000 7446.00000  0.00%     -    4s
#
# Explored 0 nodes (29736 simplex iterations) in 4.58 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7446 7163
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.446000000000e+03, best bound 7.446000000000e+03, gap 0.0000%
# Optimize a model with 100011 rows, 50500 columns and 309851 nonzeros
# Variable types: 0 continuous, 50500 integer (50500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e-01, 2e+01]
# Presolve removed 59460 rows and 28866 columns
# Presolve time: 1.08s
# Presolved: 40551 rows, 21634 columns, 163241 nonzeros
# Variable types: 0 continuous, 21634 integer (21634 binary)
# Found heuristic solution: objective 7684.0000000
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Presolve removed 3 rows and 0 columns
# Presolved: 40548 rows, 21637 columns, 162777 nonzeros
#
# Concurrent spin time: 0.84s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.915000e+03, 29260 iterations, 2.50 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7915.0000000 7915.00000  0.00%     -    3s
#
# Explored 0 nodes (29260 simplex iterations) in 4.01 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 7915 7684
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.915000000000e+03, best bound 7.915000000000e+03, gap 0.0000%
